# %%
import Pkg; Pkg.add("DifferentialEquations")
import Pkg; Pkg.add("Plots")
import Pkg; Pkg.add("Formatting")
import Pkg; Pkg.add("Catalyst")
import Pkg; Pkg.add("Noise")
import Pkg; Pkg.add("LinearAlgebra")
import Pkg; Pkg.add("Latexify")
import Pkg; Pkg.add("ModelingToolkit")
import Pkg; Pkg.add("PlotlyJS")
import Pkg; Pkg.add("MATLABDiffEq")

_ = IJulia.clear_output(true)
# Out:
# 0

# %%
using DifferentialEquations;
using Random;
using Plots;
using Formatting;
using LinearAlgebra;
using Noise;
using Catalyst;
using Latexify;
using MATLABDiffEq;

# %% [markdown]
# # Utils

# %%
# Returns the sum of concentrations of the species with a given prefix
function aggregate_values(rn, odesol; prefix='x')
    ss = species(rn)

    ret = zeros(length(odesol[1, :]))
    total = 0
    for i in 1:length(ss)
        item = ss[i]
        item_str = "$item"
        if startswith(item_str, prefix)
#             println(item_str)
            ret += odesol[i, :] # Gets the variable at index i for all time steps.
        end
    end
    return ret
end


function print_species_array(reaction_network)
    ss = species(reaction_network)
    print("species = [")
    for s in ss
        print("'", s,"'", ",")
    end
    print("]")
    
end


function simulate(rn, u0, p; tspan=(0.0, 1000.0), reltol=1e-12, abstol=1e-12)
    oprob = ODEProblem(rn, u0, tspan, p)
    sol = solve(oprob, Rosenbrock23(), reltol=reltol, abstol=abstol)
    return sol
end
# Out:
# simulate (generic function with 1 method)

# %%
unimol_autocat = @reaction_network uni begin
    k, a + G_i --> i + waste1
    k, i + G_a_a --> a + a + o + waste2
    k, o + Fl_f --> f + waste3
end k
species(unimol_autocat)
# Out:
# 10-element Vector{Term{Real, Base.ImmutableDict{DataType, Any}}}:
#  a(t)
#  G_i(t)
#  i(t)
#  waste1(t)
#  G_a_a(t)
#  o(t)
#  waste2(t)
#  Fl_f(t)
#  f(t)
#  waste3(t)

# %%
u0 = [
   1e-9, 1e-8, 0.0, 0.0, 1e-8, 0.0, 0.0, 1e-7, 0.0, 0.0
]
p = [1.5e6]
tspan = (0, 3600.0)

oprob = ODEProblem(unimol_autocat, u0, tspan, p)
sol = solve(oprob, AutoTsit5(Rosenbrock23()), reltol=1e-12, abstol=1e-12)
# Out:
# retcode: Success
# Interpolation: specialized 4th order "free" interpolation, specialized 2nd order "free" stiffness-aware interpolation
# t: 51-element Vector{Float64}:
#     0.0
#     0.25384917090392234
#     2.6349127196388364
#     7.245281663501565
#    13.061066924620281
#    20.771776166176394
#    30.55840556283736
#    43.47413902087861
#    60.904858718548724
#    82.12714118428721
#   105.76822973251076
#   131.55233503165596
#   157.62254438802705
#     ⋮
#  1031.7338283010117
#  1118.0716820205662
#  1219.3257631488848
#  1337.0669582333408
#  1476.2813062597954
#  1641.5831175177445
#  1840.3817885314197
#  2080.2485566900327
#  2372.687742732684
#  2731.0021949390375
#  3174.482756933324
#  3600.0
# u: 51-element Vector{Vector{Float64}}:
#  [1.0e-9, 1.0e-8, 0.0, 0.0, 1.0e-8, 0.0, 0.0, 1.0e-7, 0.0, 0.0]
#  [9.96214665827356e-10, 9.99620020551641e-9, 3.792564328117058e-12, 3.799794483590106e-12, 9.999992769844526e-9, 7.13919383078007e-15, 7.230155473045995e-15, 9.999999990903836e-8, 9.096164226592399e-17, 9.096164226592399e-17]
#  [9.62821245799009e-10, 9.961301302300109e-9, 3.793872595044089e-11, 3.8698697699890793e-11, 9.99924002825055e-9, 6.684255055580541e-13, 7.599717494498868e-13, 9.999990845375611e-8, 9.154624389183216e-14, 9.154624389183216e-14]
#  [9.081079179078064e-10, 9.897137710027249e-9, 9.737718603247211e-11, 1.0286228997275069e-10, 9.994514896059722e-9, 3.914944621124902e-12, 5.485103940278528e-12, 9.999842984068085e-8, 1.5701593191536238e-12, 1.5701593191536238e-12]
#  [8.551311759444624e-10, 9.82142761590083e-9, 1.6172060407735348e-10, 1.7857238409916946e-10, 9.983148219978185e-9, 9.487777434864655e-12, 1.6851780021815905e-11, 9.999263599741305e-8, 7.364002586951253e-12, 7.364002586951253e-12]
#  [8.071367605536453e-10, 9.72767842078266e-9, 2.32592409331847e-10, 2.7232157921733954e-10, 9.96027083011451e-9, 1.699660019907975e-11, 3.972916988549243e-11, 9.997726743031358e-8, 2.2732569686412675e-11, 2.2732569686412675e-11]
#  [7.740662523850455e-10, 9.61574686790052e-9, 3.0509343985721653e-10, 3.8425313209947867e-10, 9.92084030775774e-9, 2.52374141537627e-11, 7.915969224226208e-11, 9.994607772191149e-8, 5.392227808849939e-11, 5.392227808849939e-11]
#  [7.642980002997666e-10, 9.474005907195427e-9, 3.808480462524026e-10, 5.259940928045719e-10, 9.854853953447833e-9, 3.375104060453525e-11, 1.4514604655216923e-10, 9.988860499405236e-8, 1.1139500594763401e-10, 1.1139500594763401e-10]
#  [7.911365329710132e-10, 9.284042992488028e-9, 4.624102372704783e-10, 7.1595700751197e-10, 9.74645322975851e-9, 4.2315458257964653e-11, 2.5354677024149166e-10, 9.978876868801646e-8, 2.1123131198352702e-10, 2.1123131198352702e-10]
#  [8.620028949271985e-10, 9.043724756423253e-9, 5.47136174324773e-10, 9.562752435767445e-10, 9.59086093074803e-9, 5.034959453182378e-11, 4.0913906925197156e-10, 9.964121052527984e-8, 3.5878947472014784e-10, 3.5878947472014784e-10]
#  [9.717856849913307e-10, 8.755085654725065e-9, 6.365643301418009e-10, 1.2449143452749323e-9, 9.39164998486687e-9, 5.7997083680270566e-11, 6.083500151331318e-10, 9.944964706854713e-8, 5.503529314528612e-10, 5.503529314528612e-10]
#  [1.11766447103812e-9, 8.409035528651396e-9, 7.366500001552408e-10, 1.5909644713486017e-9, 9.14568552880664e-9, 6.578759299264645e-11, 8.543144711933612e-10, 9.921147312179928e-8, 7.885268782007145e-10, 7.885268782007145e-10]
#  [1.2881799446873438e-9, 8.023203462518405e-9, 8.443082963971246e-10, 1.976796537481593e-9, 8.867511758915532e-9, 7.343882609629413e-11, 1.1324882410844686e-9, 9.894095058501182e-8, 1.0590494149881742e-9, 1.0590494149881742e-9]
#  ⋮
#  [8.904612086699333e-9, 4.429191120228629e-12, 1.045479361090219e-9, 9.995570808879772e-9, 1.049908552210447e-9, 1.2310848550982646e-11, 8.950091447789553e-9, 9.106221940076141e-8, 8.937780599238569e-9, 8.937780599238569e-9]
#  [9.152545313513901e-9, 1.2685512039860963e-12, 9.230930676410562e-10, 9.998731448796014e-9, 9.243616188450417e-10, 9.55898973455307e-12, 9.075638381154958e-9, 9.093392060857958e-8, 9.066079391420404e-9, 9.066079391420404e-9]
#  [9.379324760470587e-9, 2.6599230166181703e-13, 8.102046236138756e-10, 9.999734007698338e-9, 8.104706159155368e-10, 7.347621658453213e-12, 9.189529384084463e-9, 9.081781823757398e-8, 9.182181762426008e-9, 9.182181762426008e-9]
#  [9.582356426876829e-9, 3.692185563481352e-14, 7.088033256337682e-10, 9.999963078144365e-9, 7.088402474894023e-10, 5.615914813706571e-12, 9.291159752510598e-9, 9.07144561623031e-8, 9.285543837696888e-9, 9.285543837696888e-9]
#  [9.76542145540869e-9, 2.4266053178683727e-15, 6.172880589929956e-10, 9.999997573394681e-9, 6.172904855983128e-10, 4.254760235263474e-12, 9.382709514401688e-9, 9.062154524583356e-8, 9.378454754166421e-9, 9.378454754166421e-9]
#  [9.929599620574536e-9, -5.0518850472815706e-18, 5.352001922386745e-10, 1.0000000005051885e-8, 5.352001871867887e-10, 3.19547334801654e-12, 9.464799812813213e-9, 9.053839566053478e-8, 9.461604339465193e-9, 9.461604339465193e-9]
#  [1.0077212820600569e-8, 3.2681853790387815e-19, 4.613935895363066e-10, 9.999999999673181e-9, 4.613935898631244e-10, 2.372948059468371e-12, 9.538606410136877e-9, 9.046376653792257e-8, 9.536233462077405e-9, 9.536233462077405e-9]
#  [1.0208876740136333e-8, -3.806048759578924e-20, 3.9556162995086423e-10, 1.000000000003806e-8, 3.95561629912803e-10, 1.7428778012048537e-12, 9.604438370087199e-9, 9.039730450771399e-8, 9.60269549228599e-9, 9.60269549228599e-9]
#  [1.0326127435530627e-8, 5.980556674410131e-21, 3.36936282231697e-10, 9.99999999999402e-9, 3.3693628223767684e-10, 1.2637714566653127e-12, 9.663063717762325e-9, 9.033820005369433e-8, 9.661799946305657e-9, 9.661799946305657e-9]
#  [1.0429714557567636e-8, -1.103053404113614e-21, 2.851427212167345e-10, 1.0000000000001104e-8, 2.851427212156307e-10, 9.04644333335398e-13, 9.714857278784371e-9, 9.028604736554896e-8, 9.713952634451032e-9, 9.713952634451032e-9]
#  [1.052089546163396e-8, 2.193796873110304e-22, 2.395522691829114e-10, 9.999999999999782e-9, 2.3955226918313003e-10, 6.382294582175112e-13, 9.760447730816872e-9, 9.024019049864134e-8, 9.75980950135865e-9, 9.75980950135865e-9]
#  [1.0584551777544051e-8, -4.370449389827267e-23, 2.0772411122799774e-10, 1.0000000000000045e-8, 2.0772411122795328e-10, 4.798186896552364e-13, 9.792275888772048e-9, 9.02082039299176e-8, 9.79179607008239e-9, 9.79179607008239e-9]

# %%
plot()
a = aggregate_values(unimol_autocat, sol, prefix="a")
i = aggregate_values(unimol_autocat, sol, prefix="i")
f = aggregate_values(unimol_autocat, sol, prefix="f")
plot!(sol.t, [a i f], label=["a(t)"  "i(t)" "f(t)"], legend=:topleft)
